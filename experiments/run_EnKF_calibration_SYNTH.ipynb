# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_loaders import model_names
from data_loaders import load_da

# %%
# run and plot DA with nature as synthetic data

for model_name in model_names:
    
    DA = load_da(model_name, synthetic=True)
    
    # DA.plot_1d_dists()
    
    DA.plot_matrices(excerpt=True)
    # DA.plot_matrices(excerpt=False)
# Out:
# Using specified parameter ranges to assemble dist_kwargs.
# Loaded parameter samples from  ./data/WENO_FULLRES/DYCOMS_RF01_N64_seed0/samples_parameters_unconstrained.npy
# Loading 64 samples for ensemble DYCOMS_RF01_N64_seed0...
# ... done loading samples for ensemble DYCOMS_RF01_N64_seed0.
# Loaded observation DYCOMS_RF01_N64_seed0 from ./data/WENO_FULLRES/DYCOMS_RF01_N64_seed0/samples_observations.nc.
# /cluster/work/climate/dgrund/git/dana-grund/CalPyCLES/environment/.venv/calpycles/lib/python3.9/site-packages/xarray/core/concat.py:544: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__K
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_xy
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__partial_updates
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__misfit
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_y
# Saved figure  figs/WENO_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__post_corr_transform
# Using default parameter properties in parameter ensemble init.
# Using specified parameter ranges to assemble dist_kwargs.
# Loaded parameter samples from  ./data/WENO_LOWRES/DYCOMS_RF01_N64/samples_parameters_unconstrained.npy
# Loading 64 samples for ensemble DYCOMS_RF01_N64...
# ... done loading samples for ensemble DYCOMS_RF01_N64.
# Loaded observation DYCOMS_RF01_N64 from ./data/WENO_LOWRES/DYCOMS_RF01_N64/samples_observations.nc.
# /cluster/work/climate/dgrund/git/dana-grund/CalPyCLES/environment/.venv/calpycles/lib/python3.9/site-packages/xarray/core/concat.py:544: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__K
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_xy
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__partial_updates
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__misfit
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_y
# Saved figure  figs/WENO_LOWRES/SYNTH/matrices_excerpts/fig-heatmap__post_corr_transform
# Using default parameter properties in parameter ensemble init.
# Using specified parameter ranges to assemble dist_kwargs.
# Loaded parameter samples from  ./data/MIXED_FULLRES/DYCOMS_RF01_N64/samples_parameters_unconstrained.npy
# Loading 64 samples for ensemble DYCOMS_RF01_N64...
# ... done loading samples for ensemble DYCOMS_RF01_N64.
# Loaded observation DYCOMS_RF01_N64 from ./data/MIXED_FULLRES/DYCOMS_RF01_N64/samples_observations.nc.
# /cluster/work/climate/dgrund/git/dana-grund/CalPyCLES/environment/.venv/calpycles/lib/python3.9/site-packages/xarray/core/concat.py:544: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# WARNING: Ensemble not finite. Cropping 5 samples: [ 4 25 26 45 47]
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__K
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_xy
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__partial_updates
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__misfit
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_y
# Saved figure  figs/MIXED_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__post_corr_transform
# Using default parameter properties in parameter ensemble init.
# Using specified parameter ranges to assemble dist_kwargs.
# Loaded parameter samples from  ./data/CENTRAL_FULLRES/DYCOMS_RF01_N64/samples_parameters_unconstrained.npy
# Loading 64 samples for ensemble DYCOMS_RF01_N64...
# ... done loading samples for ensemble DYCOMS_RF01_N64.
# Loaded observation DYCOMS_RF01_N64 from ./data/CENTRAL_FULLRES/DYCOMS_RF01_N64/samples_observations.nc.
# /cluster/work/climate/dgrund/git/dana-grund/CalPyCLES/environment/.venv/calpycles/lib/python3.9/site-packages/xarray/core/concat.py:544: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# WARNING: Ensemble not finite. Cropping 5 samples: [ 4 25 26 45 47]
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__K
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_xy
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__partial_updates
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__misfit
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__Corr_y
# Saved figure  figs/CENTRAL_FULLRES/SYNTH/matrices_excerpts/fig-heatmap__post_corr_transform
